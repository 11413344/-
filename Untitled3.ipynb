# %% [markdown]
# <a href="https://colab.research.google.com/github/11413344/-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1

# %%
type(a)
# Out:
# int

# %%
b='abcd'

# %%
type(b)
# Out:
# str

# %%
c=True

# %%
type(c)
# Out:
# bool

# %%
d=1.23

# %%
type(d)
# Out:
# float
